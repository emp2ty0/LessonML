# %%
# !pip install git+https://github.com/batprem/price-loaders.git
# Out:
# ...
#   Cloning https://github.com/batprem/price-loaders.git to /tmp/pip-req-build-5ifrizkq
#   Running command git clone --filter=blob:none --quiet https://github.com/batprem/price-loaders.git /tmp/pip-req-build-5ifrizkq
#   Resolved https://github.com/batprem/price-loaders.git to commit dce105b3f788900b8d24ef7b9e648d0dd63b1163
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from price_loaders.tradingview import load_asset_price

# %%
df_rual  = load_asset_price('RUAL',3650,'1H',None)

# %%
df_rual
# Out:
#                           time    open    high     low   close     volume  \
# 0    2025-01-15 19:00:00+07:00  34.810  34.810  34.680  34.800   926240.0
# 1    2025-01-15 20:00:00+07:00  34.795  34.975  34.710  34.925   764130.0
# 2    2025-01-15 21:00:00+07:00  34.920  34.965  34.770  34.910   802170.0
# 3    2025-01-15 22:00:00+07:00  34.920  35.020  34.855  34.960   835990.0
# 4    2025-01-15 23:00:00+07:00  35.010  35.905  35.005  35.700  4585430.0
# ...                        ...     ...     ...     ...     ...        ...
# 3645 2025-10-12 18:00:00+07:00  30.240  30.245  30.210  30.215     4400.0
# 3646 2025-10-12 19:00:00+07:00  30.240  30.245  30.190  30.230     6690.0
# 3647 2025-10-12 20:00:00+07:00  30.235  30.240  30.190  30.225    14510.0
# 3648 2025-10-12 21:00:00+07:00  30.220  30.225  30.205  30.220     8910.0
# 3649 2025-10-12 22:00:00+07:00  30.220  30.300  30.210  30.285    96570.0
#
#        pe_ratio
# 0      7.152253
# 1      7.177943
# 2      7.174860
# ...

# %%
df_ng  = load_asset_price('NG1!',3650,'1H',None)

# %%
df_ng.head()
# Out:
#                        time   open   high    low  close   volume
# 0 2025-03-01 02:00:00+07:00  3.864  3.865  3.827  3.850  11897.0
# 1 2025-03-01 03:00:00+07:00  3.850  3.851  3.832  3.832   3565.0
# 2 2025-03-01 04:00:00+07:00  3.833  3.834  3.814  3.819   2342.0
# 3 2025-03-03 06:00:00+07:00  3.779  3.792  3.742  3.757   2831.0
# 4 2025-03-03 07:00:00+07:00  3.759  3.763  3.752  3.760    965.0

# %%
df_btc = load_asset_price('BTCUSDT',3650,'1H',None)

# %%
df_btc.head()
# Out:
#                        time       open       high        low      close  \
# 0 2025-05-14 01:00:00+07:00  104268.17  104428.58  104081.85  104354.19
# 1 2025-05-14 02:00:00+07:00  104354.19  104976.25  104158.73  104792.22
# 2 2025-05-14 03:00:00+07:00  104792.21  104928.00  104400.00  104562.39
# 3 2025-05-14 04:00:00+07:00  104562.40  104613.32  104179.00  104342.71
# 4 2025-05-14 05:00:00+07:00  104342.70  104432.03  104100.00  104128.50
#
#        volume
# 0   667.51343
# 1  2351.90796
# 2   601.95317
# 3   391.26707
# 4   502.72511

# %%
! pip install pandas_ta

# %%
import pandas_ta as ta
import yfinance as yf

# %%
data = yf.download(tickers='AAPL',start = '2021-01-01', end = '2023-01-1')
# Out:
# /tmp/ipython-input-624210622.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers='AAPL',start = '2021-01-01', end = '2023-01-1')
# [*********************100%***********************]  1 of 1 completed

# %%
data.columns = ['_'.join(map(str, col)) for col in data.columns.to_flat_index()]

# %%
data
# Out:
#             Close_AAPL   High_AAPL    Low_AAPL   Open_AAPL  Volume_AAPL
# Date
# 2021-01-04  126.096565  130.189025  123.514415  130.101333    143301900
# 2021-01-05  127.655594  128.366914  125.141651  125.589879     97664900
# 2021-01-06  123.358536  127.694603  123.144167  124.449862    155088000
# 2021-01-07  127.567909  128.259737  124.586260  125.073458    109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251    105158200
# ...                ...         ...         ...         ...          ...
# 2022-12-23  130.026215  130.578424  127.837087  129.099285     63814900
# 2022-12-27  128.221664  129.582478  126.929885  129.552896     69007800
# 2022-12-28  124.287163  129.207765  124.119529  127.866678     85438400
# 2022-12-29  127.807510  128.665406  125.953658  126.210037     75703700
# 2022-12-30  128.123062  128.142788  125.657837  126.624212     77034200
#
# [503 rows x 5 columns]

# %%
data.columns = ['Close','High','Low','Open','Volume']

# %%
data['ema_5'] = ta.ema(data['Close'],length=5, append = True, adjust = True)

# %%
data
# Out:
#                  Close        High         Low        Open     Volume  \
# Date
# 2021-01-04  126.096565  130.189025  123.514415  130.101333  143301900
# 2021-01-05  127.655594  128.366914  125.141651  125.589879   97664900
# 2021-01-06  123.358536  127.694603  123.144167  124.449862  155088000
# 2021-01-07  127.567909  128.259737  124.586260  125.073458  109578200
# 2021-01-08  128.668991  129.234143  126.895583  129.039251  105158200
# ...                ...         ...         ...         ...        ...
# 2022-12-23  130.026215  130.578424  127.837087  129.099285   63814900
# 2022-12-27  128.221664  129.582478  126.929885  129.552896   69007800
# 2022-12-28  124.287163  129.207765  124.119529  127.866678   85438400
# 2022-12-29  127.807510  128.665406  125.953658  126.210037   75703700
# 2022-12-30  128.123062  128.142788  125.657837  126.624212   77034200
#
#                  ema_5
# Date
# 2021-01-04         NaN
# 2021-01-05         NaN
# 2021-01-06         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Close'],label = ['Close Price'],linewidth = 2)
plt.plot(data['ema_5'],label = ['5-day EMA'],linestyle = '--',linewidth = 2)
plt.title('AAPL Price with 5 day EMA')
plt.grid()
plt.legend()
plt.show()

# %%
data['sma_50'] = ta.sma(data['Close'],lenght = 50)

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Close'],label = ['Close Price'],linewidth = 2)
plt.plot(data['sma_50'],label = ['50-day SMA'],linestyle = '--',linewidth = 2)
plt.title('AAPL Price with 50 day SMA')
plt.grid()
plt.legend()
plt.show()

# %%
data['chaikin'] = ta.adosc(high=data['High'], low = data['Low'],volume=data['Volume'],close = data['Close'],fast = 3, slow = 10)

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Close'],label = ['Close Price'],linewidth = 2)
plt.plot(data['chaikin'],label = ['chaikin'],linestyle = '--',linewidth = 2)
plt.title('chaikin')
plt.grid()
plt.legend()
plt.show()
