# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine('sqlite:///:memory:')

# %%
df = pd.DataFrame(data=np.random.randint(low = 0, high = 100, size = (4,4)), columns=['a','b', 'c', 'd'])

# %%
df
# Out:
#     a   b   c   d
# 0  83  21  80  18
# 1  66   4  91  40
# 2  87  45  33   0
# 3  18  98  44  53

# %%
df.to_sql(name = 'new_table', con = temp_db, index = None)
# Out:
# 4

# %%
df_db = pd.read_sql('new_table',con = temp_db)

# %%
df_db
# Out:
#     a   b   c   d
# 0  83  21  80  18
# 1  66   4  91  40
# 2  87  45  33   0
# 3  18  98  44  53

# %%
pd.read_sql_query(sql = 'SELECT * FROM new_table', con = temp_db)
# Out:
#     a   b   c   d
# 0  83  21  80  18
# 1  66   4  91  40
# 2  87  45  33   0
# 3  18  98  44  53
