# %% [markdown]
# https://drive.google.com/file/d/1SlNxhp4gS3_YODQDg71cGtiHsNVcf7QL/view?usp=drive_link

# %%
! gdown --id 1SlNxhp4gS3_YODQDg71cGtiHsNVcf7QL
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SlNxhp4gS3_YODQDg71cGtiHsNVcf7QL
# To: /content/churn-modeling.zip
# 100% 268k/268k [00:00<00:00, 76.6MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/churn-modeling.zip')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isna().mean()
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Exited'].value_counts(normalize=True)
# Out:
# Exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Делаем stratify что бы процентов оттока было одинаково

# %%
train,test = train_test_split(df,train_size = 0.6, random_state = 42,stratify = df['Exited'])

# %%
val,test = train_test_split(test,train_size = 0.5, random_state = 42,stratify = test['Exited'])

# %%
train_full = pd.concat([train,val])

# %%
train_full
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 6851       6852    15779103  Cantamessa          527   Germany  Female   39
# 7026       7027    15588123      Horton          677    France  Female   27
# 5705       5706    15698703     Doherty          628   Germany    Male   40
# 9058       9059    15802560       Moran          470     Spain  Female   48
# 9415       9416    15750407        Hunt          768   Germany  Female   43
# ...         ...         ...         ...          ...       ...     ...  ...
# 926         927    15628303    Thurgood          738     Spain    Male   35
# 6727       6728    15610416    Christie          745    France  Female   36
# 4745       4746    15655410      Hinton          768   Germany    Male   49
# 1307       1308    15638806   Blackburn          645     Spain    Male   49
# 7464       7465    15569682      Leckie          768   Germany    Male   37
#
# ...

# %%
! pip install phik
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 13.0 MB/s eta 0:00:00
# ...

# %%
import phik

# %%
phik_info = train_full.phik_matrix()
# Out:
# interval columns not set, guessing: ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
# /usr/local/lib/python3.12/dist-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable Surname is large: 2591. Are you sure this is not an interval variable? Analysis for pairs of variables including Surname can be slow.
#   warnings.warn(

# %%
import seaborn as sns

# %%
sns.heatmap(phik_info)
# Out:
# <Axes: >

# %%
phik_info['Exited'].sort_values(ascending=False)
# Out:
# Exited             1.000000
# NumOfProducts      0.564965
# Age                0.498241
# IsActiveMember     0.237256
# Balance            0.167823
# Gender             0.165240
# CreditScore        0.123343
# Geography          0.104041
# CustomerId         0.035798
# Tenure             0.033611
# Surname            0.000000
# RowNumber          0.000000
# HasCrCard          0.000000
# EstimatedSalary    0.000000
# Name: Exited, dtype: float64
