# %% [markdown]
# https://drive.google.com/file/d/1ZTNXon2x_e20QNhrokVbwX16zTH9XvsD/view?usp=drive_link

# %% [markdown]
# https://www.kaggle.com/datasets/adityadesai13/used-car-dataset-ford-and-mercedes

# %%
! gdown --id 1ZTNXon2x_e20QNhrokVbwX16zTH9XvsD
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1ZTNXon2x_e20QNhrokVbwX16zTH9XvsD
# To: /content/uk-userd-cars.zip
# 100% 1.15M/1.15M [00:00<00:00, 13.0MB/s]

# %%
! unzip /content/uk-userd-cars.zip -d /content/uk-userd-cars/
# Out:
# Archive:  /content/uk-userd-cars.zip
# replace /content/uk-userd-cars/audi.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/uk-userd-cars/bmw.csv')

# %%
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df,random_state = 42)

# %%
len(train)
# Out:
# 8085

# %%
len(test)
# Out:
# 2696

# %%
len(df) == (len(train) + len(test))
# Out:
# True

# %%
len(test) / len(df)
# Out:
# 0.2500695668305352

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize
# 930          2.0
# 4052         1.5
# 1197         3.0
# 7893         2.0
# 7571         1.5
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
sns.heatmap(train[['year','mileage','tax','mpg','engineSize','price']].corr())
# Out:
# <Axes: >

# %%
train['year_cut'] = pd.cut(train['year'],5)

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut
# 930          2.0  (2010.4, 2015.2]
# 4052         1.5  (2015.2, 2020.0]
# ...

# %%
train.groupby('year')['price'].median().plot()
# Out:
# <Axes: xlabel='year'>

# %%
train[train['year'] == 2015]
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 1197          X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7571    1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# 10096   1 Series  2015  11000       Manual    40829   Diesel   20  70.6
# 4344    2 Series  2015  19140    Semi-Auto    12117   Petrol  260  35.8
# 10218   3 Series  2015  13400    Automatic    24741   Diesel   30  62.8
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10627   1 Series  2015  11000    Automatic    25345   Petrol  145  48.7
# 1528    2 Series  2015   9995       Manual    37500   Diesel   20  68.9
# 7734          X5  2015  24990    Automatic    60000   Diesel  200  47.1
# 1899    3 Series  2015  18555    Semi-Auto    51416   Diesel  145  53.3
# 4555    2 Series  2015  10998    Semi-Auto    51719   Diesel   20  68.9
#
#        engineSize          year_cut
# 1197          3.0  (2010.4, 2015.2]
# ...

# %%
train['price'].describe()
# Out:
# count      8085.000000
# mean      22668.821645
# std       11469.825387
# min        1445.000000
# 25%       14800.000000
# 50%       20022.000000
# 75%       27850.000000
# max      123456.000000
# Name: price, dtype: float64

# %%
train['price_pred_mean'] = train['price'].mean()

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean
# 930          2.0  (2010.4, 2015.2]     22668.821645
# ...

# %%
train['err'] = train['price_pred_mean'] - train['price']

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err
# ...

# %%
train['err_abs'] = abs(train['err'])

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
train['err_abs_pct'] = train['err_abs'] / train['price']

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
train['err_abs_pct'].describe()
# Out:
# count    8085.000000
# mean        0.483169
# std         0.678706
# min         0.000052
# 25%         0.153833
# 50%         0.312962
# 75%         0.587825
# max        14.687766
# Name: err_abs_pct, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
mean_absolute_error(train['price'],train['price_pred_mean'])
# Out:
# 8450.556631461715

# %%
train['err_abs'].mean() == mean_absolute_error(train['price'],train['price_pred_mean'])
# Out:
# np.True_

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_mean'])
# Out:
# 0.48316912602731443

# %%
train['err_abs_pct'].mean() == mean_absolute_percentage_error(train['price'],train['price_pred_mean'])
# Out:
# np.True_

# %%
train['price_pred_median'] = train['price'].median()

# %%
mean_absolute_error(train['price'],train['price_pred_median'])
# Out:
# 8220.5146567718

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_median'])
# Out:
# 0.41711111879393314

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
model_year_mean = train.groupby('year')['price'].mean().reset_index()

# %%
model_year_mean
# Out:
#     year         price
# 0   1996   5995.000000
# 1   1997   3950.000000
# 2   1998   3950.000000
# 3   1999   3980.000000
# 4   2000   1550.000000
# 5   2001   7333.333333
# 6   2002   3893.500000
# 7   2003   9222.500000
# 8   2004   7932.857143
# 9   2005   5390.166667
# 10  2006   5445.250000
# 11  2007   5027.833333
# 12  2008   6004.666667
# 13  2009   6506.090909
# 14  2010   7374.129032
# 15  2011   8860.297297
# 16  2012   9432.923913
# 17  2013  11041.347826
# 18  2014  13411.333333
# 19  2015  15086.536313
# 20  2016  16531.655222
# 21  2017  19205.839506
# 22  2018  22562.450394
# 23  2019  31066.986143
# 24  2020  35359.445652

# %%
model_year_mean = model_year_mean.rename({'price': 'price_pred_year_mean'},axis=1)

# %%
model_year_mean
# Out:
#     year  price_pred_year_mean
# 0   1996           5995.000000
# 1   1997           3950.000000
# 2   1998           3950.000000
# 3   1999           3980.000000
# 4   2000           1550.000000
# 5   2001           7333.333333
# 6   2002           3893.500000
# 7   2003           9222.500000
# 8   2004           7932.857143
# 9   2005           5390.166667
# 10  2006           5445.250000
# 11  2007           5027.833333
# 12  2008           6004.666667
# 13  2009           6506.090909
# 14  2010           7374.129032
# 15  2011           8860.297297
# 16  2012           9432.923913
# 17  2013          11041.347826
# 18  2014          13411.333333
# 19  2015          15086.536313
# 20  2016          16531.655222
# 21  2017          19205.839506
# 22  2018          22562.450394
# 23  2019          31066.986143
# 24  2020          35359.445652

# %%
train = train.merge(model_year_mean, how = 'left',on = 'year')

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
mean_absolute_error(train['price'],train['price_pred_year_mean'])
# Out:
# 5474.243598515644

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_year_mean'])
# Out:
# 0.2447228468704618

# %%
model_year_median = train.groupby('year')['price'].median().reset_index()

# %%
model_year_median
# Out:
#     year    price
# 0   1996   5995.0
# 1   1997   3950.0
# 2   1998   3950.0
# 3   1999   3995.0
# 4   2000   1550.0
# 5   2001   5950.0
# 6   2002   3494.5
# 7   2003   9222.5
# 8   2004   3495.0
# 9   2005   4685.0
# 10  2006   3942.5
# 11  2007   4597.5
# 12  2008   5272.5
# 13  2009   5845.0
# 14  2010   6495.0
# 15  2011   8470.0
# 16  2012   8990.0
# 17  2013  10490.0
# 18  2014  12797.5
# 19  2015  14103.5
# 20  2016  15699.5
# 21  2017  18299.5
# 22  2018  21000.0
# 23  2019  27980.0
# 24  2020  32450.5

# %%
model_year_median = model_year_median.rename({'price': 'price_pred_year_median'},axis=1)

# %%
train = train.merge(model_year_median, how = 'left', on = 'year')

# %%
mean_absolute_error(train['price'],train['price_pred_year_median'])
# Out:
# 5232.327891156463

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_year_median'])
# Out:
# 0.21723436816638503

# %%
train.groupby('engineSize')['price'].agg(['count','mean','median'])
# Out:
#             count          mean   median
# engineSize
# 0.0            32  18469.906250  18250.0
# 0.6             6  17973.333333  18200.0
# 1.0             1  17400.000000  17400.0
# 1.5          1146  17104.345550  15881.5
# 1.6            75   9230.240000   8890.0
# 1.9             5   3968.000000   3950.0
# 2.0          4925  20697.721624  19792.0
# 2.2             4   6010.000000   3972.5
# 2.5             8   4532.375000   3892.5
# 2.8             1   5995.000000   5995.0
# 3.0          1818  31545.723872  27058.0
# 3.2             3  16116.333333  17850.0
# 3.5             1   6990.000000   6990.0
# 4.0             4  18012.250000  17700.0
# 4.4            54  49960.666667  45904.5
# 5.0             1  12495.000000  12495.0
# 6.6             1  57000.000000  57000.0

# %%
def order_engineSize(x):
  if x <=1.5:
    return '<=1,5'
  if x <=2:
    return '<=2'
  return '>2'

# %%
train['engineSize'].apply(order_engineSize)
# Out:
# 0         <=2
# 1       <=1,5
# 2          >2
# 3         <=2
# 4       <=1,5
#         ...
# 8080      <=2
# 8081       >2
# 8082      <=2
# 8083      <=2
# 8084    <=1,5
# Name: engineSize, Length: 8085, dtype: object

# %%
train['engine_group'] = train['engineSize'].apply(order_engineSize)

# %%
train.groupby(['year','engine_group'])['price'].median().reset_index()
# Out:
#     year engine_group    price
# 0   1996           >2   5995.0
# 1   1997          <=2   3950.0
# 2   1998          <=2   3950.0
# 3   1999          <=2   3995.0
# 4   2000           >2   1550.0
# 5   2001        <=1,5  13000.0
# 6   2001           >2   4500.0
# 7   2002          <=2   3999.0
# 8   2002           >2   2990.0
# 9   2003           >2   9222.5
# 10  2004          <=2   1970.0
# 11  2004           >2   8750.0
# 12  2005          <=2   4375.0
# 13  2005           >2   4995.0
# 14  2006          <=2   2992.5
# 15  2006           >2   5344.5
# 16  2007          <=2   3495.0
# 17  2007           >2   5994.0
# 18  2008          <=2   3992.5
# 19  2008           >2   7642.5
# 20  2009          <=2   4740.0
# 21  2009           >2   9490.0
# 22  2010          <=2   5995.0
# 23  2010           >2   9125.0
# 24  2011          <=2   7624.0
# 25  2011           >2  10500.0
# 26  2012          <=2   8500.0
# 27  2012           >2  12970.0
# 28  2013          <=2   9990.0
# ...

# %%
model_year_engine_median = train.groupby(['year','engine_group'])['price'].median().reset_index()

# %%
t = train.pivot_table(index = 'year',columns = 'engine_group',values='price')

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='engine_group', ylabel='year'>

# %%
model_year_engine_median
# Out:
#     year engine_group    price
# 0   1996           >2   5995.0
# 1   1997          <=2   3950.0
# 2   1998          <=2   3950.0
# 3   1999          <=2   3995.0
# 4   2000           >2   1550.0
# 5   2001        <=1,5  13000.0
# 6   2001           >2   4500.0
# 7   2002          <=2   3999.0
# 8   2002           >2   2990.0
# 9   2003           >2   9222.5
# 10  2004          <=2   1970.0
# 11  2004           >2   8750.0
# 12  2005          <=2   4375.0
# 13  2005           >2   4995.0
# 14  2006          <=2   2992.5
# 15  2006           >2   5344.5
# 16  2007          <=2   3495.0
# 17  2007           >2   5994.0
# 18  2008          <=2   3992.5
# 19  2008           >2   7642.5
# 20  2009          <=2   4740.0
# 21  2009           >2   9490.0
# 22  2010          <=2   5995.0
# 23  2010           >2   9125.0
# 24  2011          <=2   7624.0
# 25  2011           >2  10500.0
# 26  2012          <=2   8500.0
# 27  2012           >2  12970.0
# 28  2013          <=2   9990.0
# ...

# %%
model_year_engine_median = model_year_engine_median.rename({'price':'price_pred_egine_median'},axis=1)

# %%
model_year_engine_median
# Out:
#     year engine_group  price_pred_egine_median
# 0   1996           >2                   5995.0
# 1   1997          <=2                   3950.0
# 2   1998          <=2                   3950.0
# 3   1999          <=2                   3995.0
# 4   2000           >2                   1550.0
# 5   2001        <=1,5                  13000.0
# 6   2001           >2                   4500.0
# 7   2002          <=2                   3999.0
# 8   2002           >2                   2990.0
# 9   2003           >2                   9222.5
# 10  2004          <=2                   1970.0
# 11  2004           >2                   8750.0
# 12  2005          <=2                   4375.0
# 13  2005           >2                   4995.0
# 14  2006          <=2                   2992.5
# 15  2006           >2                   5344.5
# 16  2007          <=2                   3495.0
# 17  2007           >2                   5994.0
# 18  2008          <=2                   3992.5
# ...

# %%
train = train.merge(model_year_engine_median, how = 'left', on = ['year','engine_group'])

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
mean_absolute_error(train['price'],train['price_pred_egine_median'])
# Out:
# 3659.774273345702

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_egine_median'])
# Out:
# 0.1582922021242831

# %%
test['engine_group'] = test['engineSize'].apply(order_engineSize)

# %%
test = test.merge(model_year_engine_median, how ='left',on = ['year','engine_group'])

# %%
test.isna().mean()
# Out:
# model                      0.000000
# year                       0.000000
# price                      0.000000
# transmission               0.000000
# mileage                    0.000000
# fuelType                   0.000000
# tax                        0.000000
# mpg                        0.000000
# engineSize                 0.000000
# engine_group               0.000000
# price_pred_egine_median    0.000742
# dtype: float64

# %%
test[test['price_pred_egine_median'].isna()]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 415    3 Series  1999   1200    Automatic    82000   Petrol  245  31.0
# 2255   5 Series  2000   1699       Manual    99209   Petrol  265  29.4
#
#       engineSize engine_group  price_pred_egine_median
# 415          2.8           >2                      NaN
# 2255         2.0          <=2                      NaN

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 0      1 Series  2018  15300       Manual    36469   Diesel  150   50.4
# 1      5 Series  2014  15495    Semi-Auto    51565   Diesel  160   51.4
# 2            X3  2019  39875    Semi-Auto     8988   Diesel  150   36.7
# 3      2 Series  2019  21730    Automatic     5054   Petrol  145   39.2
# 4      2 Series  2018  13799       Manual    13369   Diesel  145   65.7
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 2691   4 Series  2019  25500    Automatic     3250   Petrol  145   48.7
# 2692   7 Series  2019  52700    Semi-Auto      706   Diesel  145   44.1
# 2693   3 Series  2017  15795    Automatic    64000   Hybrid    0  134.5
# 2694   4 Series  2019  29840    Automatic     6000   Diesel  145   60.1
# 2695   4 Series  2020  34980    Semi-Auto     1000   Petrol  145   48.7
#
#       engineSize engine_group  price_pred_egine_median
# ...

# %%
def error(y_true, y_pred):
  print(mean_absolute_error(y_true,y_pred))
  print(mean_absolute_percentage_error(y_true,y_pred))

# %%
test_no_na = test.dropna().copy()

# %%
error(test_no_na['price'],test_no_na['price_pred_egine_median'])
# Out:
# 3790.014291017075
# 0.16270961023342095

# %%
train.groupby('year')['price'].agg(['count','mean'])
# Out:
#       count          mean
# year
# 1996      1   5995.000000
# 1997      1   3950.000000
# 1998      1   3950.000000
# 1999      3   3980.000000
# 2000      1   1550.000000
# 2001      3   7333.333333
# 2002      4   3893.500000
# 2003      2   9222.500000
# 2004      7   7932.857143
# 2005      6   5390.166667
# 2006     12   5445.250000
# 2007     12   5027.833333
# 2008     18   6004.666667
# 2009     22   6506.090909
# 2010     31   7374.129032
# 2011     37   8860.297297
# 2012     92   9432.923913
# 2013    253  11041.347826
# 2014    384  13411.333333
# 2015    716  15086.536313
# 2016   1398  16531.655222
# 2017   1296  19205.839506
# 2018    635  22562.450394
# 2019   2598  31066.986143
# 2020    552  35359.445652

# %%
train['year_group'] = pd.cut(train['year'],[0,2010,2012,2014,2016,2018,float('inf')])

# %%
train.groupby(['year_group'])['price'].agg(['count','mean'])
# Out:
# /tmp/ipython-input-2054187939.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train.groupby(['year_group'])['price'].agg(['count','mean'])
#                   count          mean
# year_group
# (0.0, 2010.0]       124   6264.258065
# (2010.0, 2012.0]    129   9268.682171
# (2012.0, 2014.0]    637  12470.036107
# (2014.0, 2016.0]   2114  16042.201514
# (2016.0, 2018.0]   1931  20309.644744
# (2018.0, inf]      3150  31819.188571

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  price_pred_mean           err  \
# ...

# %%
model_year_engine_median_group = train.groupby(['year_group','engine_group'])['price'].median().reset_index()
# Out:
# /tmp/ipython-input-3943896953.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   model_year_engine_median_group = train.groupby(['year_group','engine_group'])['price'].median().reset_index()

# %%
model_year_engine_median_group
# Out:
#           year_group engine_group    price
# 0      (0.0, 2010.0]        <=1,5  13000.0
# 1      (0.0, 2010.0]          <=2   4097.0
# 2      (0.0, 2010.0]           >2   6990.0
# 3   (2010.0, 2012.0]        <=1,5      NaN
# 4   (2010.0, 2012.0]          <=2   8470.0
# 5   (2010.0, 2012.0]           >2  12245.0
# 6   (2012.0, 2014.0]        <=1,5  14972.5
# 7   (2012.0, 2014.0]          <=2  10998.0
# 8   (2012.0, 2014.0]           >2  16345.0
# 9   (2014.0, 2016.0]        <=1,5  11557.0
# 10  (2014.0, 2016.0]          <=2  14800.0
# 11  (2014.0, 2016.0]           >2  19497.5
# 12  (2016.0, 2018.0]        <=1,5  14999.0
# 13  (2016.0, 2018.0]          <=2  18980.0
# 14  (2016.0, 2018.0]           >2  24480.0
# 15     (2018.0, inf]        <=1,5  21500.0
# 16     (2018.0, inf]          <=2  27990.0
# 17     (2018.0, inf]           >2  46000.0

# %%
model_year_engine_median_group = model_year_engine_median_group.rename({'price': 'price_pred_engine_median_group'},axis=1)

# %%
train = train.merge(model_year_engine_median_group, how = 'left', on = ['year_group','engine_group'])

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  ...           err       err_abs  \
# ...

# %%
error(train['price'],train['price_pred_engine_median_group'])
# Out:
# 3827.4336425479282
# 0.1693848259731495

# %%
train.groupby('transmission')['price'].agg(['count','median','mean'])
# Out:
#               count   median          mean
# transmission
# Automatic      2698  19392.0  22413.452187
# Manual         1925  13450.0  14557.851429
# Semi-Auto      3462  24990.0  27377.835066

# %%
model_year_engine_trans_median_group = train.groupby(['year_group','engine_group','transmission'])['price'].median().reset_index()
# Out:
# /tmp/ipython-input-3173463261.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   model_year_engine_trans_median_group = train.groupby(['year_group','engine_group','transmission'])['price'].median().reset_index()

# %%
model_year_engine_trans_median_group = model_year_engine_trans_median_group.rename({'price':'price_pred_engine_trans_median_group'},axis=1)

# %%
sum(model_year_engine_trans_median_group['price_pred_engine_trans_median_group'].isna())
# Out:
# 10

# %%
train = train.merge(model_year_engine_trans_median_group, how = 'left', on = ['year_group','engine_group','transmission'])

# %%
error(train['price'],train['price_pred_engine_trans_median_group'])
# Out:
# 3635.5412492269634
# 0.1561691679065392

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize          year_cut  ...       err_abs  err_abs_pct  \
# ...
